# %% [markdown]
# "Food":'fdc_id','data_type', 'description'
# Where the fdc_id is the unique permament identifier of a food in the food table
#
# Agricultural adquisition: Non-processed foods obtained directly from the location where they are produced
#
# branded food: Foods whose nutrient values are obtained from food label data provided by food brand owners

# %%
import pandas as pd
data = pd.read_csv('../data/raw/FoodData_Central_csv_2023-04-20/food.csv')

# %%
data
# Out:
#           fdc_id          data_type  \
# 0        1105904       branded_food
# 1        1105905       branded_food
# 2        1105906       branded_food
# 3        1105907       branded_food
# 4        1105898  experimental_food
# ...          ...                ...
# 1913734  2554910       branded_food
# 1913735  2554911       branded_food
# 1913736  2554912       branded_food
# 1913737  2554913       branded_food
# 1913738  2554914       branded_food
#
#                                                description  food_category_id  \
# 0                               WESSON Vegetable Oil 1 GAL               NaN
# 1                                       SWANSON BROTH BEEF               NaN
# 2                 CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER               NaN
# 3              CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI               NaN
# 4        Discrepancy between the Atwater factor predict...               NaN
# ...
