# %% [markdown]
# # EDA on Food.com: Recipes and Interactions
#
# This dataset was obtained from [this link](https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions).
#
# This dataset consists of 180K+ recipes and 700K+ recipe reviews covering 18 years of user interactions and uploads on Food.com (formerly GeniusKitchen). used in the following paper:
#
# [Generating Personalized Recipes from Historical User Preferences Bodhisattwa Prasad Majumder, Shuyang Li, Jianmo Ni, Julian McAuley EMNLP, 2019](https://www.aclweb.org/anthology/D19-1613)
#
#
# There is a preprocessed data that starts with the `PP` suffix, and then there is the raw data with the `raw` suffix.

# %%
import pandas as pd
import os

# %%
data_path = '../data/raw/'
raw_data_file = 'RAW_recipes.csv'
processed_data_file = 'PP_recipes.csv'
ingredient_map_file = 'ingr_map.pkl'

raw_data_path = os.path.join(data_path, raw_data_file)
processed_data_path = os.path.join(data_path, processed_data_file)
ingredient_map_path = os.path.join(data_path, ingredient_map_file)

ingredient_map = pd.read_pickle(ingredient_map_path)
raw_data = pd.read_csv(raw_data_path)
processed_data = pd.read_csv(processed_data_path)

# %%
# Aux functions:
def techinques(lst):
    indices = [i for i, x in enumerate(lst) if x == 1]
    techinques_vals = [TECHNIQUES_LIST[i] for i in indices]
    return techinques_vals

# %%
# Add functionality to data

raw_data['nutrition_list'] = raw_data.nutrition.str.replace('[','').str.replace(']','').str.split(', ')
raw_data['nutrition_list'] = raw_data.nutrition_list.explode().astype('float').groupby(level=0).apply(lambda x: x.to_list())
raw_data['ingredients']  = raw_data.ingredients.str.replace('[','').str.replace(']','').str.replace("'", '').str.split(', ')

# According to Kaggle link the correct order is the following: 
raw_data['calories__nb'] = raw_data['nutrition_list'].apply(lambda x: x[0])
raw_data['total_fat__pvd'] = raw_data['nutrition_list'].apply(lambda x: x[1])
raw_data['sugar__pvd'] = raw_data['nutrition_list'].apply(lambda x: x[2])
raw_data['sodium__pvd'] = raw_data['nutrition_list'].apply(lambda x: x[3])
raw_data['protein__pvd'] = raw_data['nutrition_list'].apply(lambda x: x[4])
raw_data['sat_fat__pvd'] = raw_data['nutrition_list'].apply(lambda x: x[5])
raw_data['carbs__pvd'] = raw_data['nutrition_list'].apply(lambda x: x[6])
raw_data.drop(['nutrition', 'nutrition_list'], axis=1)

# According to the code in the official repo: 
# https://github.com/majumderb/recipe-personalization/blob/master/recipe_gen/language.py these are the techniques not encoded. 
TECHNIQUES_LIST = [
    'bake',
    'barbecue',
    'blanch',
    'blend',
    'boil',
    'braise',
    'brine',
    'broil',
    'caramelize',
    'combine',
    'crock pot',
    'crush',
    'deglaze',
    'devein',
    'dice',
    'distill',
    'drain',
    'emulsify',
    'ferment',
    'freez',
    'fry',
    'grate',
    'griddle',
    'grill',
    'knead',
    'leaven',
    'marinate',
    'mash',
    'melt',
    'microwave',
    'parboil',
    'pickle',
    'poach',
    'pour',
    'pressure cook',
    'puree',
    'refrigerat',
    'roast',
    'saute',
    'scald',
    'scramble',
    'shred',
    'simmer',
    'skillet',
    'slow cook',
    'smoke',
    'smooth',
    'soak',
    'sous-vide',
    'steam',
    'stew',
    'strain',
    'tenderize',
    'thicken',
    'toast',
    'toss',
    'whip',
    'whisk',
]
processed_data['ingredient_ids_list'] = processed_data.ingredient_ids.str.replace('[','').str.replace(']','').str.split(', ')
processed_data['techniques_list'] = processed_data.techniques.str.replace('[','').str.replace(']','').str.split(', ')
processed_data['techniques_list'] = processed_data.techniques_list.explode().astype('int').groupby(level=0).apply(lambda x: x.to_list())
processed_data['techniques_list'] = processed_data.techniques_list.apply(techinques)

# %%
reduced_ingredient_map = ingredient_map[['replaced','id']].drop_duplicates('id').rename(columns={'id':'ingredient_ids_list'})
reduced_ingredient_map['ingredient_ids_list'] = reduced_ingredient_map['ingredient_ids_list'].astype('str')
processed_data_ingredient_list = processed_data[['id', 'ingredient_ids_list']]\
.explode('ingredient_ids_list')\
.merge(reduced_ingredient_map, on='ingredient_ids_list', how='left')\
.groupby('id')\
.agg(ingredient_list = ('replaced', lambda x: x.to_list()))\
.reset_index()

# %%
raw_data_relevant_features = ['name', 'id', 'minutes', 'tags', 'n_steps', 'steps', 'ingredients', 'n_ingredients']
nutritional_features = ['calories__nb', 'total_fat__pvd', 'sugar__pvd', 'sodium__pvd', 'protein__pvd', 'sat_fat__pvd', 'carbs__pvd']
data = raw_data[
    raw_data_relevant_features + nutritional_features
].copy()
data = data\
.merge(processed_data_ingredient_list, on='id', how='inner')\
.merge(processed_data[['id', 'calorie_level', 'techniques_list']], on='id', how='inner')

# %%
data.head(3)
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                          alouette  potatoes   59389       45
#
#                                                 tags  n_steps  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 1  ['30-minutes-or-less', 'time-to-make', 'course...        9
# 2  ['60-minutes-or-less', 'time-to-make', 'course...       11
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['place potatoes in a large pot of lightly sal...
#
#                                          ingredients  n_ingredients  \
# 0  [winter squash, mexican seasoning, mixed spice...              7
# 1  [prepared pizza crust, sausage patty, eggs, mi...              6
# 2  [spreadable cheese with garlic and herbs, new ...             11
#
#    calories__nb  total_fat__pvd  sugar__pvd  sodium__pvd  protein__pvd  \
# 0          51.5             0.0        13.0          0.0           2.0
# 1         173.4            18.0         0.0         17.0          22.0
# 2         368.1            17.0        10.0          2.0          14.0
#
#    sat_fat__pvd  carbs__pvd  \
# 0           0.0         4.0
# 1          35.0         1.0
# 2           8.0        20.0
#
#                                      ingredient_list  calorie_level  \
# 0  [winter squash, mexican seasoning, mixed spice...              0
# 1  [pizza crust, sausage, egg, milk, salt and pep...              0
# 2  [cheese, new potato, shallot, parsley, tarrago...              1
#
#              techniques_list
# 0        [bake, grate, melt]
# 1        [bake, pour, whisk]
# 2  [bake, boil, dice, drain]

# %%
data_sample = data.sample(1)
data_sample.ingredients.iloc[0], data_sample.ingredient_list.iloc[0]
# Out:
# (['water',
#   'dried split peas',
#   'chicken broth',
#   'ham bone',
#   'dried marjoram',
#   'black pepper',
#   'bay leaf',
#   'carrots',
#   'celery ribs',
#   'onion'],
#  ['water',
#   'dried split pea',
#   'chicken broth',
#   'ham bone',
#   'dried marjoram',
#   'black pepper',
#   'bay leaf',
#   'carrot',
#   'celery rib',
#   'onion'])

# %%
exploded_ingredients = data.ingredient_list.explode()
exploded_ingredients.loc[exploded_ingredients=='garlic clove'] = 'garlic'
exploded_ingredients.loc[exploded_ingredients=='garlic clove'] = 'garlic'

# %%
exploded_ingredients[exploded_ingredients.str.contains('vegan')].value_counts()
# Out:
# ingredient_list
# vegan margarine                     73
# vegan chocolate chip                22
# vegan butter                        21
# vegan sugar                         16
# vegan parmesan cheese               15
# vegan sour cream                    12
# vegan chicken seasoning              6
# vegan egg replacer powder            6
# vegan worcestershire sauce           5
# vegan burger                         5
# vegan cheese                         5
# non-hydrogenated vegan margarine     5
# vegan chicken                        5
# vegan egg substitute                 3
# vegan powdered sugar                 2
# vegan chocolate                      2
# vegan pie crust                      1
# Name: count, dtype: int64

# %%
data[data.name.str.contains(' vegan')]
# Out:
#                                             name      id  minutes  \
# 14             cream  of cauliflower soup  vegan   23850      110
# 16                 cream  of spinach soup  vegan   24701       55
# 69                sour cream  avocado dip  vegan  112959       10
# 135     cream   of pumpkin or squash soup  vegan  164526       30
# 138              creamy   vegan potato leek soup  343338       40
# ...                                          ...     ...      ...
# 177118           yummy whole wheat bread   vegan  327738      220
# 177136            yummy    vegan pumpkin cookies  208051       12
# 177210         zen habits vegan three bean chili  230854       45
# 177803                  zucchini brownies  vegan  384645       40
# 177997       zucchini pasta primavera  raw vegan  433946       20
#
#                                                      tags  n_steps  \
# 14      ['lactose', 'weeknight', 'time-to-make', 'cour...       10
# 16      ['60-minutes-or-less', 'time-to-make', 'course...       10
# 69      ['lactose', '15-minutes-or-less', 'time-to-mak...        6
# 135     ['30-minutes-or-less', 'time-to-make', 'course...        9
# 138     ['lactose', '60-minutes-or-less', 'time-to-mak...       10
# ...                                                   ...      ...
# 177118  ['time-to-make', 'course', 'preparation', 'hea...        9
# 177136  ['15-minutes-or-less', 'time-to-make', 'course...        6
# 177210  ['60-minutes-or-less', 'time-to-make', 'course...        5
# 177803  ['lactose', '60-minutes-or-less', 'time-to-mak...        7
# 177997  ['30-minutes-or-less', 'time-to-make', 'course...        3
#
#                                                     steps  \
# 14      ['heat the oil or margarine in a soup pot and ...
# 16      ['in a 3 qt saucepan over medium high heat , s...
# 69      ['peel and pit avocado , put in a large mixing...
# 135     ['place all ingredients except for banana , ap...
# 138     ['heat olive oil in a 4-quart pot', 'sautee th...
# ...                                                   ...
# 177118  ['in a large bowl dissolve the yeast in the wa...
# 177136  ['pour oil in mixing bowl', 'add sugar and pum...
# 177210  ['heat olive oil on medium-high heat', 'saute ...
# 177803  ['preheat oven to 350 and spray a 9x13 baking ...
# 177997  ['blend or mash avocado & lemon juice together...
#
#                                               ingredients  n_ingredients  \
# 14      [canola oil, onion, garlic, cauliflower, potat...             16
# 16      [onion, scallion, apple juice, olive oil, spin...             12
# 69      [soft silken tofu, avocado, chunky salsa, fres...              7
# 135     [pumpkin puree, vegetable broth, small red pot...             14
# 138     [olive oil, leeks, garlic cloves, russet potat...              8
# ...                                                   ...            ...
# 177118  [active dry yeast, warm water, grapeseed oil, ...              6
# 177136  [olive oil, sugar, pumpkin, vanilla extract, a...              9
# 177210  [vegetarian ground beef, pinto beans, kidney b...             13
# 177803  [applesauce, raw sugar, maple syrup, vanilla, ...             11
# 177997  [avocado, lemon, zucchini, celery, cherry toma...              7
#
#         calories__nb  total_fat__pvd  sugar__pvd  sodium__pvd  protein__pvd  \
# 14             174.2             4.0        24.0          1.0          15.0
# 16              64.8             3.0        13.0         54.0           4.0
# 69              12.8             1.0         0.0          0.0           0.0
# 135             89.3             0.0        35.0          0.0           4.0
# 138            183.0             3.0        10.0          0.0          13.0
# ...              ...             ...         ...          ...           ...
# 177118        1478.3            35.0       112.0        122.0         102.0
# 177136         115.4             7.0        34.0          3.0           2.0
# 177210         334.2            10.0        46.0         48.0          40.0
# 177803          78.6             0.0        36.0          7.0           3.0
# 177997         272.4            25.0        64.0          3.0          17.0
#
#         sat_fat__pvd  carbs__pvd  \
# 14               1.0        10.0
# 16               2.0         3.0
# 69               0.0         0.0
# 135              0.0         7.0
# 138              1.0        11.0
# ...              ...         ...
# 177118          14.0        96.0
# 177136           3.0         5.0
# 177210           4.0        16.0
# 177803           1.0         6.0
# 177997          12.0        10.0
#
#                                           ingredient_list  calorie_level  \
# 14      [canola oil, onion, garlic, cauliflower, potat...              0
# 16      [onion, scallion, apple juice, olive oil, spin...              0
# 69      [soft silken tofu, avocado, chunky salsa, fres...              0
# 135     [pumpkin puree, vegetable broth, small red pot...              0
# 138     [olive oil, leek, garlic clove, russet potato,...              0
# ...                                                   ...            ...
# 177118  [yeast, warm water, grapeseed oil, brown sugar...              2
# 177136  [olive oil, sugar, pumpkin, vanilla extract, a...              0
# 177210  [vegetarian ground beef, pinto bean, kidney be...              1
# 177803  [applesauce, raw sugar, maple syrup, vanilla, ...              0
# 177997  [avocado, lemon, zucchini, celery, cherry toma...              1
#
#                                     techniques_list
# 14            [blend, puree, saute, simmer, smooth]
# 16      [blend, boil, puree, saute, simmer, smooth]
# 69                         [blend, combine, smooth]
# 135                                         [puree]
# 138     [blend, boil, puree, saute, simmer, smooth]
# ...                                             ...
# 177118                        [bake, knead, smooth]
# 177136                                 [bake, pour]
# 177210                        [saute, simmer, stew]
# 177803                              [bake, combine]
# 177997                    [blend, mash, pour, toss]
#
# [552 rows x 18 columns]

# %%
data[data.name.str.contains('vegan') & data.name.str.contains('meat')]
# Out:
#                                                   name      id  minutes  \
# 60637   easy tofu no meat balls  vegan and gluten free  361658       20
# 63979                        favorite meat loaf  vegan  414222       60
# 91667        kottbullar  swedish meatless balls  vegan  426757       94
# 165190                  tofu walnut  meatballs   vegan  467898       50
# 170131                                vegan  meatballs  416845       25
# 170178             vegan beefless burgers or meatballs   21566       40
# 170360                 vegan meatless loaf with seitan  290989       65
# 170361                               vegan meatloaf  1  254279      120
# 170878                     vegetarian   vegan meatloaf  363490       70
# 171273                    veggie lunch meat  vegan dad  376410      145
# 172452                         walnut meatballs  vegan  239125       45
#
#                                                      tags  n_steps  \
# 60637   ['30-minutes-or-less', 'time-to-make', 'course...        4
# 63979   ['60-minutes-or-less', 'time-to-make', 'prepar...        8
# 91667   ['time-to-make', 'course', 'main-ingredient', ...       11
# 165190  ['60-minutes-or-less', 'time-to-make', 'course...       10
# 170131  ['30-minutes-or-less', 'time-to-make', 'prepar...        4
# 170178  ['60-minutes-or-less', 'time-to-make', 'course...        9
# 170360  ['time-to-make', 'course', 'main-ingredient', ...        9
# 170361  ['lactose', 'time-to-make', 'course', 'main-in...       13
# 170878  ['time-to-make', 'preparation', 'easy', 'vegan...       10
# 171273  ['time-to-make', 'course', 'main-ingredient', ...       17
# 172452  ['lactose', '60-minutes-or-less', 'time-to-mak...        9
#
#                                                     steps  \
# 60637   ['combine first 6 ingredients in medium mixing...
# 63979   ['preheat oven to 350 degrees f , then oil an ...
# 91667   ['place potatoes in medium saucepan , cover wi...
# 165190  ['mix first 4 ingredients in a large bowl', 'a...
# 170131  ['combine all ingredients in a bowl or electri...
# 170178  ['combine all ingredients', 'mix well', 'use l...
# 170360  ['preheat oven to 350', 'soften oatmeal in 1 /...
# 170361  ['pulse the pine nuts in a food processor unti...
# 170878  ['preheat oven to 350', 'grind walnuts in food...
# 171273  ['method', 'get water steaming in your steamer...
# 172452  ['in food processor , pure the water and onion...
#
#                                               ingredients  n_ingredients  \
# 60637   [firm tofu, quick oats, braggs liquid aminos, ...              9
# 63979   [sesame oil, onions, carrot, fresh garlic, dri...             12
# 91667   [potatoes, vegetable bouillon cube, ground alm...              7
# 165190  [bread, walnuts, oats, diced onion, garlic pow...             12
# 170131  [lightlife gimme lean ground sausage, veggie c...             11
# 170178  [textured vegetable protein, water, sunflower ...             12
# 170360  [oats, seitan, bulgar wheat, rice, tofu, olive...             19
# 170361  [black beans, carrots, onion, celery ribs, zuc...             18
# 170878  [walnuts, celery ribs, yellow onion, garlic cl...             12
# 171273  [white beans, water, oil, salt, paprika, onion...             13
# 172452  [onion, water, fresh parsley, chicken-flavored...              9
#
#         calories__nb  total_fat__pvd  sugar__pvd  sodium__pvd  protein__pvd  \
# 60637          212.0            13.0         3.0          0.0          27.0
# 63979           64.3             6.0         7.0          6.0           1.0
# 91667          427.3            43.0        13.0          0.0          19.0
# 165190         300.2            26.0        10.0         30.0          30.0
# 170131         117.4            10.0         0.0          6.0           2.0
# 170178         199.1            16.0        13.0         20.0          15.0
# 170360         364.9            14.0         9.0         17.0          29.0
# 170361         278.2            20.0        18.0         17.0          19.0
# 170878         173.5            13.0        10.0         51.0          20.0
# 171273         834.4            86.0         6.0        209.0          43.0
# 172452          42.4             4.0         1.0          0.0           3.0
#
#         sat_fat__pvd  carbs__pvd  \
# 60637            7.0         7.0
# 63979            2.0         2.0
# 91667           15.0        12.0
# 165190          10.0         8.0
# 170131           4.0         4.0
# 170178           5.0         6.0
# 170360           6.0        19.0
# 170361           6.0        11.0
# 170878           4.0         5.0
# 171273          37.0        22.0
# 172452           1.0         1.0
#
#                                           ingredient_list  calorie_level  \
# 60637   [firm tofu, quick oat, braggs liquid amino, fr...              0
# 63979   [sesame oil, onion, carrot, fresh garlic, drie...              0
# 91667   [potato, vegetable bouillon cube, ground almon...              1
# 165190  [bread, walnut, oat, diced onion, garlic powde...              1
# 170131  [sausage, veggie crumble, cracker crumb, onion...              0
# 170178  [textured vegetable protein, water, sunflower ...              0
# 170360  [oat, seitan, bulgar wheat, rice, tofu, olive ...              1
# 170361  [black bean, carrot, onion, celery rib, zucchi...              1
# 170878  [walnut, celery rib, yellow onion, garlic clov...              0
# 171273  [white bean, water, oil, salt, paprika, onion ...              2
# 172452  [onion, water, fresh parsley, chicken vegetari...              0
#
#                                       techniques_list
# 60637                                [combine, saute]
# 63979          [bake, blend, combine, saute, skillet]
# 91667            [boil, drain, fry, mash, pour, soak]
# 165190                  [bake, combine, drain, freez]
# 170131                                      [combine]
# 170178                   [bake, combine, fry, pickle]
# 170360                  [bake, combine, drain, freez]
# 170361                            [bake, mash, steam]
# 170878  [bake, barbecue, drain, mash, saute, skillet]
# 171273             [bake, blend, pour, smooth, steam]
# 172452                           [bake, pour, smooth]
